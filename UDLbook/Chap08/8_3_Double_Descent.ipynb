# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.201093, train error 81.43,  test loss 2.167893, test error 81.68
# Epoch   100, train loss 1.880442, train error 71.12,  test loss 1.722944, test error 69.47
# Epoch   200, train loss 1.867717, train error 69.35,  test loss 1.728310, test error 67.60
# Epoch   300, train loss 1.861671, train error 70.85,  test loss 1.711165, test error 69.25
# Epoch   400, train loss 1.859846, train error 70.70,  test loss 1.722519, test error 69.03
# Epoch   500, train loss 1.875335, train error 71.60,  test loss 1.737145, test error 70.43
# Epoch   600, train loss 1.858089, train error 70.15,  test loss 1.727715, test error 67.85
# Epoch   700, train loss 1.864514, train error 69.82,  test loss 1.734679, test error 68.35
# Epoch   800, train loss 1.856851, train error 70.20,  test loss 1.724876, test error 69.75
# Epoch   900, train loss 1.872527, train error 69.72,  test loss 1.751132, test error 69.00
# Training model with   4 hidden variables
# Epoch     0, train loss 2.285197, train error 88.00,  test loss 2.283522, test error 87.10
# Epoch   100, train loss 1.787991, train error 65.12,  test loss 1.642313, test error 64.75
# Epoch   200, train loss 1.769052, train error 65.10,  test loss 1.618917, test error 62.92
# Epoch   300, train loss 1.759884, train error 64.45,  test loss 1.615722, test error 62.97
# Epoch   400, train loss 1.757136, train error 64.50,  test loss 1.614772, test error 63.30
# Epoch   500, train loss 1.756353, train error 64.88,  test loss 1.616142, test error 63.20
# Epoch   600, train loss 1.753224, train error 64.93,  test loss 1.613770, test error 63.65
# Epoch   700, train loss 1.753076, train error 64.07,  test loss 1.615848, test error 63.53
# Epoch   800, train loss 1.761029, train error 64.90,  test loss 1.626064, test error 63.20
# Epoch   900, train loss 1.753635, train error 64.50,  test loss 1.623470, test error 63.53
# Training model with   6 hidden variables
# Epoch     0, train loss 2.236097, train error 82.93,  test loss 2.210252, test error 81.12
# Epoch   100, train loss 1.720585, train error 63.62,  test loss 1.568324, test error 61.38
# Epoch   200, train loss 1.658137, train error 60.47,  test loss 1.511922, test error 57.62
# Epoch   300, train loss 1.643675, train error 59.53,  test loss 1.498552, test error 58.15
# Epoch   400, train loss 1.623815, train error 58.70,  test loss 1.472057, test error 57.47
# Epoch   500, train loss 1.618917, train error 57.92,  test loss 1.489667, test error 56.92
# Epoch   600, train loss 1.607547, train error 57.72,  test loss 1.474841, test error 57.65
# Epoch   700, train loss 1.620228, train error 58.50,  test loss 1.485964, test error 57.78
# Epoch   800, train loss 1.610748, train error 59.05,  test loss 1.483896, test error 57.83
# Epoch   900, train loss 1.613534, train error 58.03,  test loss 1.485868, test error 57.55
# Training model with   8 hidden variables
# Epoch     0, train loss 2.252341, train error 86.28,  test loss 2.250918, test error 85.65
# Epoch   100, train loss 1.644238, train error 57.47,  test loss 1.493425, test error 57.30
# Epoch   200, train loss 1.602835, train error 57.20,  test loss 1.471032, test error 56.80
# Epoch   300, train loss 1.584680, train error 56.60,  test loss 1.467590, test error 56.35
# Epoch   400, train loss 1.570372, train error 55.62,  test loss 1.470193, test error 56.22
# Epoch   500, train loss 1.562336, train error 56.40,  test loss 1.478025, test error 55.97
# Epoch   600, train loss 1.552389, train error 56.60,  test loss 1.473993, test error 56.22
# Epoch   700, train loss 1.545432, train error 55.45,  test loss 1.476362, test error 56.65
# Epoch   800, train loss 1.541811, train error 56.30,  test loss 1.488532, test error 57.17
# Epoch   900, train loss 1.539928, train error 55.25,  test loss 1.495592, test error 57.03
# Training model with  10 hidden variables
# Epoch     0, train loss 2.268424, train error 84.88,  test loss 2.273752, test error 84.60
# Epoch   100, train loss 1.521549, train error 52.58,  test loss 1.382616, test error 52.03
# Epoch   200, train loss 1.453711, train error 50.75,  test loss 1.365631, test error 51.05
# Epoch   300, train loss 1.431776, train error 49.62,  test loss 1.373666, test error 51.67
# Epoch   400, train loss 1.428097, train error 50.03,  test loss 1.395262, test error 51.75
# Epoch   500, train loss 1.409150, train error 48.58,  test loss 1.381617, test error 51.65
# Epoch   600, train loss 1.406543, train error 49.15,  test loss 1.384063, test error 51.47
# Epoch   700, train loss 1.401648, train error 47.78,  test loss 1.393327, test error 51.65
# Epoch   800, train loss 1.406616, train error 48.42,  test loss 1.407475, test error 52.30
# Epoch   900, train loss 1.397436, train error 48.75,  test loss 1.407316, test error 51.85
# Training model with  14 hidden variables
# Epoch     0, train loss 2.215385, train error 82.78,  test loss 2.195086, test error 83.45
# Epoch   100, train loss 1.527803, train error 53.25,  test loss 1.462186, test error 57.33
# Epoch   200, train loss 1.454563, train error 51.03,  test loss 1.468526, test error 56.28
# Epoch   300, train loss 1.409812, train error 49.92,  test loss 1.483376, test error 56.45
# Epoch   400, train loss 1.394401, train error 49.33,  test loss 1.484251, test error 55.90
# Epoch   500, train loss 1.368269, train error 48.58,  test loss 1.503977, test error 56.22
# Epoch   600, train loss 1.369388, train error 49.10,  test loss 1.538326, test error 55.92
# Epoch   700, train loss 1.358662, train error 48.30,  test loss 1.533692, test error 55.78
# Epoch   800, train loss 1.351830, train error 47.92,  test loss 1.542510, test error 56.40
# Epoch   900, train loss 1.342797, train error 47.28,  test loss 1.541617, test error 55.62
# Training model with  18 hidden variables
# Epoch     0, train loss 2.167879, train error 81.32,  test loss 2.119078, test error 78.85
# Epoch   100, train loss 1.334673, train error 43.53,  test loss 1.259549, test error 47.90
# Epoch   200, train loss 1.238598, train error 40.55,  test loss 1.289064, test error 47.53
# Epoch   300, train loss 1.192227, train error 39.42,  test loss 1.304698, test error 47.92
# Epoch   400, train loss 1.168234, train error 39.22,  test loss 1.347311, test error 49.25
# Epoch   500, train loss 1.158367, train error 38.50,  test loss 1.370024, test error 49.20
# Epoch   600, train loss 1.150196, train error 38.75,  test loss 1.417682, test error 50.80
# Epoch   700, train loss 1.133663, train error 37.95,  test loss 1.439748, test error 50.55
# Epoch   800, train loss 1.130341, train error 38.70,  test loss 1.460768, test error 51.25
# Epoch   900, train loss 1.132239, train error 38.22,  test loss 1.452103, test error 49.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.146818, train error 80.25,  test loss 2.085890, test error 79.78
# Epoch   100, train loss 1.308150, train error 42.58,  test loss 1.374443, test error 51.45
# Epoch   200, train loss 1.163871, train error 39.05,  test loss 1.385109, test error 50.28
# Epoch   300, train loss 1.106655, train error 37.28,  test loss 1.438688, test error 50.75
# Epoch   400, train loss 1.074008, train error 36.53,  test loss 1.509602, test error 51.28
# Epoch   500, train loss 1.041525, train error 34.50,  test loss 1.550798, test error 52.17
# Epoch   600, train loss 1.018951, train error 34.05,  test loss 1.634996, test error 52.60
# Epoch   700, train loss 1.012528, train error 34.35,  test loss 1.691560, test error 52.17
# Epoch   800, train loss 0.988017, train error 33.05,  test loss 1.728327, test error 52.35
# Epoch   900, train loss 0.988503, train error 33.60,  test loss 1.770730, test error 52.62
# Training model with  26 hidden variables
# Epoch     0, train loss 2.165890, train error 81.05,  test loss 2.136711, test error 79.75
# Epoch   100, train loss 1.207204, train error 39.78,  test loss 1.330436, test error 49.12
# Epoch   200, train loss 1.057442, train error 35.38,  test loss 1.434577, test error 51.15
# Epoch   300, train loss 0.985451, train error 32.62,  test loss 1.550585, test error 52.20
# Epoch   400, train loss 0.936620, train error 32.38,  test loss 1.629319, test error 53.15
# Epoch   500, train loss 0.919693, train error 31.45,  test loss 1.722701, test error 53.40
# Epoch   600, train loss 0.907508, train error 31.62,  test loss 1.810695, test error 53.55
# Epoch   700, train loss 0.887459, train error 30.57,  test loss 1.877634, test error 54.97
# Epoch   800, train loss 0.856666, train error 30.03,  test loss 1.924033, test error 54.58
# Epoch   900, train loss 0.847871, train error 30.18,  test loss 1.994106, test error 54.90
# Training model with  30 hidden variables
# Epoch     0, train loss 2.205203, train error 80.65,  test loss 2.191312, test error 79.82
# Epoch   100, train loss 1.073085, train error 36.05,  test loss 1.290863, test error 47.28
# Epoch   200, train loss 0.907667, train error 30.78,  test loss 1.448121, test error 49.12
# Epoch   300, train loss 0.810623, train error 27.20,  test loss 1.666494, test error 50.72
# Epoch   400, train loss 0.755454, train error 25.22,  test loss 1.887847, test error 52.83
# Epoch   500, train loss 0.725187, train error 24.45,  test loss 2.066472, test error 53.65
# Epoch   600, train loss 0.680335, train error 22.80,  test loss 2.214303, test error 54.08
# Epoch   700, train loss 0.685086, train error 23.90,  test loss 2.376427, test error 53.58
# Epoch   800, train loss 0.658415, train error 22.38,  test loss 2.559042, test error 55.72
# Epoch   900, train loss 0.648120, train error 21.72,  test loss 2.613497, test error 54.95
# Training model with  35 hidden variables
# Epoch     0, train loss 2.168334, train error 80.25,  test loss 2.161932, test error 80.32
# Epoch   100, train loss 1.040827, train error 33.60,  test loss 1.363816, test error 49.97
# Epoch   200, train loss 0.790133, train error 25.15,  test loss 1.653227, test error 51.90
# Epoch   300, train loss 0.664983, train error 21.07,  test loss 2.037982, test error 53.22
# Epoch   400, train loss 0.611654, train error 20.22,  test loss 2.441648, test error 54.92
# Epoch   500, train loss 0.531247, train error 16.93,  test loss 2.767486, test error 54.50
# Epoch   600, train loss 0.505836, train error 16.32,  test loss 3.049126, test error 55.33
# Epoch   700, train loss 0.484355, train error 16.43,  test loss 3.316308, test error 55.08
# Epoch   800, train loss 0.458695, train error 15.88,  test loss 3.564624, test error 56.60
# Epoch   900, train loss 0.446771, train error 15.28,  test loss 3.772350, test error 55.50
# Training model with  40 hidden variables
# Epoch     0, train loss 2.085232, train error 77.70,  test loss 2.050838, test error 78.57
# Epoch   100, train loss 0.938334, train error 30.30,  test loss 1.378549, test error 48.08
# Epoch   200, train loss 0.675193, train error 21.35,  test loss 1.815134, test error 51.70
# Epoch   300, train loss 0.523067, train error 16.68,  test loss 2.396422, test error 53.38
# Epoch   400, train loss 0.400376, train error 12.85,  test loss 3.145513, test error 54.45
# Epoch   500, train loss 0.353794, train error 11.93,  test loss 3.942709, test error 55.33
# Epoch   600, train loss 0.333497, train error 12.10,  test loss 4.676372, test error 57.03
# Epoch   700, train loss 0.294969, train error 10.03,  test loss 5.329699, test error 56.75
# Epoch   800, train loss 0.339700, train error 12.03,  test loss 6.113875, test error 58.33
# Epoch   900, train loss 0.238986, train error 8.88,  test loss 6.585311, test error 57.08
# Training model with  45 hidden variables
# Epoch     0, train loss 2.144328, train error 79.05,  test loss 2.142891, test error 80.20
# Epoch   100, train loss 0.883409, train error 28.28,  test loss 1.500423, test error 52.15
# Epoch   200, train loss 0.527687, train error 16.25,  test loss 2.208449, test error 53.15
# Epoch   300, train loss 0.376702, train error 12.35,  test loss 3.146816, test error 54.47
# Epoch   400, train loss 0.251133, train error 8.03,  test loss 4.255338, test error 56.55
# Epoch   500, train loss 0.175508, train error 5.03,  test loss 5.455910, test error 57.40
# Epoch   600, train loss 0.193024, train error 6.85,  test loss 6.503531, test error 55.97
# Epoch   700, train loss 0.179743, train error 5.88,  test loss 7.670976, test error 57.03
# Epoch   800, train loss 0.117342, train error 3.82,  test loss 8.738782, test error 56.97
# Epoch   900, train loss 0.091735, train error 3.03,  test loss 9.636320, test error 57.53
# Training model with  50 hidden variables
# Epoch     0, train loss 2.102974, train error 78.70,  test loss 2.046412, test error 76.97
# Epoch   100, train loss 0.733014, train error 23.78,  test loss 1.555664, test error 49.65
# Epoch   200, train loss 0.357403, train error 10.35,  test loss 2.511219, test error 53.15
# Epoch   300, train loss 0.187384, train error 5.53,  test loss 3.988237, test error 54.40
# Epoch   400, train loss 0.060001, train error 0.97,  test loss 5.567614, test error 55.12
# Epoch   500, train loss 0.014604, train error 0.00,  test loss 6.661333, test error 55.72
# Epoch   600, train loss 0.009108, train error 0.00,  test loss 7.332281, test error 55.58
# Epoch   700, train loss 0.006479, train error 0.00,  test loss 7.829495, test error 55.78
# Epoch   800, train loss 0.004920, train error 0.00,  test loss 8.227502, test error 55.95
# Epoch   900, train loss 0.003980, train error 0.00,  test loss 8.553800, test error 56.00
# Training model with  55 hidden variables
# Epoch     0, train loss 2.056567, train error 76.68,  test loss 2.011882, test error 75.82
# Epoch   100, train loss 0.628898, train error 19.62,  test loss 1.666520, test error 51.03
# Epoch   200, train loss 0.216033, train error 4.85,  test loss 3.089356, test error 54.45
# Epoch   300, train loss 0.036630, train error 0.03,  test loss 4.783027, test error 54.90
# Epoch   400, train loss 0.013117, train error 0.00,  test loss 5.822682, test error 55.35
# Epoch   500, train loss 0.007882, train error 0.00,  test loss 6.449418, test error 55.78
# Epoch   600, train loss 0.005456, train error 0.00,  test loss 6.881442, test error 55.62
# Epoch   700, train loss 0.004110, train error 0.00,  test loss 7.214851, test error 55.42
# Epoch   800, train loss 0.003223, train error 0.00,  test loss 7.491421, test error 55.53
# Epoch   900, train loss 0.002653, train error 0.00,  test loss 7.726870, test error 55.62
# Training model with  60 hidden variables
# Epoch     0, train loss 2.042929, train error 76.30,  test loss 1.974601, test error 76.32
# Epoch   100, train loss 0.540407, train error 16.97,  test loss 1.822053, test error 51.75
# Epoch   200, train loss 0.115852, train error 1.38,  test loss 3.481101, test error 54.45
# Epoch   300, train loss 0.019673, train error 0.00,  test loss 4.889351, test error 55.50
# Epoch   400, train loss 0.009496, train error 0.00,  test loss 5.626009, test error 55.78
# Epoch   500, train loss 0.005995, train error 0.00,  test loss 6.101650, test error 55.95
# Epoch   600, train loss 0.004337, train error 0.00,  test loss 6.446620, test error 55.83
# Epoch   700, train loss 0.003288, train error 0.00,  test loss 6.730264, test error 55.92
# Epoch   800, train loss 0.002656, train error 0.00,  test loss 6.957709, test error 56.08
# Epoch   900, train loss 0.002196, train error 0.00,  test loss 7.153662, test error 56.03
# Training model with  70 hidden variables
# Epoch     0, train loss 2.091842, train error 76.38,  test loss 2.080830, test error 77.53
# Epoch   100, train loss 0.357967, train error 8.22,  test loss 1.990150, test error 51.67
# Epoch   200, train loss 0.032111, train error 0.00,  test loss 3.758619, test error 53.70
# Epoch   300, train loss 0.010606, train error 0.00,  test loss 4.565336, test error 53.38
# Epoch   400, train loss 0.006023, train error 0.00,  test loss 5.017893, test error 53.58
# Epoch   500, train loss 0.004034, train error 0.00,  test loss 5.327180, test error 53.62
# Epoch   600, train loss 0.003002, train error 0.00,  test loss 5.568552, test error 53.85
# Epoch   700, train loss 0.002356, train error 0.00,  test loss 5.762644, test error 53.78
# Epoch   800, train loss 0.001929, train error 0.00,  test loss 5.925830, test error 53.62
# Epoch   900, train loss 0.001622, train error 0.00,  test loss 6.068334, test error 53.60
# Training model with  80 hidden variables
# Epoch     0, train loss 2.006346, train error 75.12,  test loss 1.957073, test error 75.28
# Epoch   100, train loss 0.242199, train error 4.12,  test loss 2.079122, test error 52.45
# Epoch   200, train loss 0.021652, train error 0.00,  test loss 3.436809, test error 52.42
# Epoch   300, train loss 0.008446, train error 0.00,  test loss 4.030663, test error 52.35
# Epoch   400, train loss 0.004957, train error 0.00,  test loss 4.372548, test error 52.47
# Epoch   500, train loss 0.003400, train error 0.00,  test loss 4.616794, test error 52.45
# Epoch   600, train loss 0.002549, train error 0.00,  test loss 4.805538, test error 52.42
# Epoch   700, train loss 0.002023, train error 0.00,  test loss 4.958698, test error 52.45
# Epoch   800, train loss 0.001662, train error 0.00,  test loss 5.088279, test error 52.50
# Epoch   900, train loss 0.001403, train error 0.00,  test loss 5.200631, test error 52.42
# Training model with  90 hidden variables
# Epoch     0, train loss 2.019018, train error 75.22,  test loss 1.949639, test error 74.35
# Epoch   100, train loss 0.147947, train error 1.20,  test loss 2.257082, test error 52.65
# Epoch   200, train loss 0.014869, train error 0.00,  test loss 3.344909, test error 53.60
# Epoch   300, train loss 0.006543, train error 0.00,  test loss 3.800288, test error 53.53
# Epoch   400, train loss 0.004005, train error 0.00,  test loss 4.082130, test error 53.55
# Epoch   500, train loss 0.002806, train error 0.00,  test loss 4.280712, test error 53.60
# Epoch   600, train loss 0.002131, train error 0.00,  test loss 4.438441, test error 53.50
# Epoch   700, train loss 0.001703, train error 0.00,  test loss 4.565854, test error 53.40
# Epoch   800, train loss 0.001409, train error 0.00,  test loss 4.673784, test error 53.45
# Epoch   900, train loss 0.001195, train error 0.00,  test loss 4.767980, test error 53.55
# Training model with 100 hidden variables
# Epoch     0, train loss 1.995770, train error 73.00,  test loss 1.911889, test error 73.20
# Epoch   100, train loss 0.084223, train error 0.12,  test loss 2.242419, test error 51.67
# Epoch   200, train loss 0.011694, train error 0.00,  test loss 3.050624, test error 51.58
# Epoch   300, train loss 0.005487, train error 0.00,  test loss 3.404498, test error 51.97
# Epoch   400, train loss 0.003434, train error 0.00,  test loss 3.617171, test error 51.88
# Epoch   500, train loss 0.002441, train error 0.00,  test loss 3.777490, test error 52.05
# Epoch   600, train loss 0.001870, train error 0.00,  test loss 3.902323, test error 51.95
# Epoch   700, train loss 0.001503, train error 0.00,  test loss 4.002439, test error 51.97
# Epoch   800, train loss 0.001249, train error 0.00,  test loss 4.089544, test error 51.85
# Epoch   900, train loss 0.001064, train error 0.00,  test loss 4.164587, test error 51.95
# Training model with 120 hidden variables
# Epoch     0, train loss 2.000855, train error 73.57,  test loss 1.938987, test error 75.28
# Epoch   100, train loss 0.053828, train error 0.03,  test loss 2.225760, test error 50.10
# Epoch   200, train loss 0.009669, train error 0.00,  test loss 2.827539, test error 50.33
# Epoch   300, train loss 0.004789, train error 0.00,  test loss 3.108751, test error 50.58
# Epoch   400, train loss 0.003065, train error 0.00,  test loss 3.289565, test error 50.60
# Epoch   500, train loss 0.002210, train error 0.00,  test loss 3.423574, test error 50.83
# Epoch   600, train loss 0.001709, train error 0.00,  test loss 3.529675, test error 50.88
# Epoch   700, train loss 0.001381, train error 0.00,  test loss 3.619001, test error 50.97
# Epoch   800, train loss 0.001152, train error 0.00,  test loss 3.694692, test error 51.00
# Epoch   900, train loss 0.000985, train error 0.00,  test loss 3.759902, test error 50.90
# Training model with 140 hidden variables
# Epoch     0, train loss 1.930201, train error 70.82,  test loss 1.848141, test error 72.12
# Epoch   100, train loss 0.036147, train error 0.00,  test loss 2.301368, test error 50.97
# Epoch   200, train loss 0.007971, train error 0.00,  test loss 2.820988, test error 51.38
# Epoch   300, train loss 0.004074, train error 0.00,  test loss 3.068573, test error 51.28
# Epoch   400, train loss 0.002653, train error 0.00,  test loss 3.229897, test error 51.47
# Epoch   500, train loss 0.001930, train error 0.00,  test loss 3.350026, test error 51.25
# Epoch   600, train loss 0.001501, train error 0.00,  test loss 3.445111, test error 51.25
# Epoch   700, train loss 0.001219, train error 0.00,  test loss 3.523862, test error 51.20
# Epoch   800, train loss 0.001021, train error 0.00,  test loss 3.592375, test error 51.28
# Epoch   900, train loss 0.000875, train error 0.00,  test loss 3.651205, test error 51.30
# Training model with 160 hidden variables
# Epoch     0, train loss 1.919852, train error 69.60,  test loss 1.849145, test error 71.88
# Epoch   100, train loss 0.028244, train error 0.00,  test loss 2.064938, test error 48.25
# Epoch   200, train loss 0.007056, train error 0.00,  test loss 2.469782, test error 48.45
# Epoch   300, train loss 0.003712, train error 0.00,  test loss 2.667196, test error 48.33
# Epoch   400, train loss 0.002435, train error 0.00,  test loss 2.797417, test error 48.33
# Epoch   500, train loss 0.001785, train error 0.00,  test loss 2.894541, test error 48.40
# Epoch   600, train loss 0.001393, train error 0.00,  test loss 2.972441, test error 48.50
# Epoch   700, train loss 0.001135, train error 0.00,  test loss 3.036095, test error 48.42
# Epoch   800, train loss 0.000953, train error 0.00,  test loss 3.091417, test error 48.40
# Epoch   900, train loss 0.000818, train error 0.00,  test loss 3.138265, test error 48.45
# Training model with 180 hidden variables
# Epoch     0, train loss 1.930485, train error 70.85,  test loss 1.865292, test error 72.60
# Epoch   100, train loss 0.025334, train error 0.00,  test loss 2.102068, test error 49.40
# Epoch   200, train loss 0.006779, train error 0.00,  test loss 2.462755, test error 49.00
# Epoch   300, train loss 0.003624, train error 0.00,  test loss 2.645708, test error 48.83
# Epoch   400, train loss 0.002395, train error 0.00,  test loss 2.766867, test error 48.72
# Epoch   500, train loss 0.001761, train error 0.00,  test loss 2.857864, test error 48.78
# Epoch   600, train loss 0.001379, train error 0.00,  test loss 2.931418, test error 48.78
# Epoch   700, train loss 0.001125, train error 0.00,  test loss 2.992280, test error 48.80
# Epoch   800, train loss 0.000946, train error 0.00,  test loss 3.045452, test error 48.80
# Epoch   900, train loss 0.000813, train error 0.00,  test loss 3.090563, test error 48.85
# Training model with 200 hidden variables
# Epoch     0, train loss 1.904105, train error 68.85,  test loss 1.826411, test error 70.25
# Epoch   100, train loss 0.021059, train error 0.00,  test loss 1.991173, test error 47.95
# Epoch   200, train loss 0.006064, train error 0.00,  test loss 2.296610, test error 47.33
# Epoch   300, train loss 0.003301, train error 0.00,  test loss 2.458890, test error 47.38
# Epoch   400, train loss 0.002202, train error 0.00,  test loss 2.566771, test error 47.35
# Epoch   500, train loss 0.001627, train error 0.00,  test loss 2.646739, test error 47.33
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.712431, test error 47.45
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.766916, test error 47.45
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.814282, test error 47.45
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.855482, test error 47.50
# Training model with 250 hidden variables
# Epoch     0, train loss 1.921180, train error 70.05,  test loss 1.865119, test error 72.57
# Epoch   100, train loss 0.016705, train error 0.00,  test loss 1.892049, test error 47.00
# Epoch   200, train loss 0.005292, train error 0.00,  test loss 2.141509, test error 47.33
# Epoch   300, train loss 0.002950, train error 0.00,  test loss 2.273496, test error 47.12
# Epoch   400, train loss 0.001995, train error 0.00,  test loss 2.363542, test error 46.92
# Epoch   500, train loss 0.001486, train error 0.00,  test loss 2.432534, test error 46.88
# Epoch   600, train loss 0.001173, train error 0.00,  test loss 2.488060, test error 46.78
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.534265, test error 46.83
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.574411, test error 46.65
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.609529, test error 46.65
# Training model with 300 hidden variables
# Epoch     0, train loss 1.876402, train error 68.20,  test loss 1.791553, test error 68.55
# Epoch   100, train loss 0.014687, train error 0.00,  test loss 1.932316, test error 47.58
# Epoch   200, train loss 0.004853, train error 0.00,  test loss 2.167941, test error 47.12
# Epoch   300, train loss 0.002740, train error 0.00,  test loss 2.293578, test error 46.92
# Epoch   400, train loss 0.001866, train error 0.00,  test loss 2.380480, test error 46.95
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.446654, test error 46.97
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.499776, test error 47.08
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.544872, test error 47.03
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.583230, test error 47.05
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.617168, test error 46.90
# Training model with 400 hidden variables
# Epoch     0, train loss 1.851001, train error 66.80,  test loss 1.759485, test error 67.82
# Epoch   100, train loss 0.011719, train error 0.00,  test loss 1.783100, test error 46.45
# Epoch   200, train loss 0.004193, train error 0.00,  test loss 1.961627, test error 46.25
# Epoch   300, train loss 0.002427, train error 0.00,  test loss 2.062704, test error 46.33
# Epoch   400, train loss 0.001671, train error 0.00,  test loss 2.131745, test error 46.22
# Epoch   500, train loss 0.001259, train error 0.00,  test loss 2.184808, test error 46.25
# Epoch   600, train loss 0.001002, train error 0.00,  test loss 2.228855, test error 46.38
# Epoch   700, train loss 0.000828, train error 0.00,  test loss 2.265391, test error 46.28
# Epoch   800, train loss 0.000703, train error 0.00,  test loss 2.296778, test error 46.25
# Epoch   900, train loss 0.000609, train error 0.00,  test loss 2.324695, test error 46.28

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
