# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if type(layer_in) == nn.Linear:
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.571437, train error 59.20,  test loss 1.646768, test error 66.30
# Epoch     1, train loss 1.339792, train error 49.33,  test loss 1.464133, test error 57.10
# Epoch     2, train loss 1.181848, train error 42.75,  test loss 1.378811, test error 55.30
# Epoch     3, train loss 1.060498, train error 37.90,  test loss 1.299664, test error 51.90
# Epoch     4, train loss 0.920360, train error 32.88,  test loss 1.213341, test error 47.10
# Epoch     5, train loss 0.846307, train error 30.70,  test loss 1.183734, test error 45.80
# Epoch     6, train loss 0.730568, train error 25.30,  test loss 1.163598, test error 43.40
# Epoch     7, train loss 0.626856, train error 19.90,  test loss 1.093108, test error 42.00
# Epoch     8, train loss 0.575612, train error 19.25,  test loss 1.114014, test error 41.60
# Epoch     9, train loss 0.514147, train error 17.65,  test loss 1.098719, test error 40.50
# Epoch    10, train loss 0.417011, train error 12.20,  test loss 1.068320, test error 40.00
# Epoch    11, train loss 0.380890, train error 10.78,  test loss 1.070085, test error 36.90
# Epoch    12, train loss 0.335976, train error 8.82,  test loss 1.078690, test error 37.90
# Epoch    13, train loss 0.301931, train error 7.18,  test loss 1.059580, test error 37.20
# Epoch    14, train loss 0.270557, train error 5.97,  test loss 1.077798, test error 36.90
# Epoch    15, train loss 0.245910, train error 4.72,  test loss 1.088479, test error 37.30
# Epoch    16, train loss 0.226868, train error 4.40,  test loss 1.112405, test error 37.00
# Epoch    17, train loss 0.211116, train error 4.12,  test loss 1.122518, test error 37.00
# Epoch    18, train loss 0.182921, train error 3.05,  test loss 1.116728, test error 36.30
# Epoch    19, train loss 0.161030, train error 1.90,  test loss 1.133118, test error 36.40
# Epoch    20, train loss 0.144388, train error 1.45,  test loss 1.148779, test error 36.00
# Epoch    21, train loss 0.134352, train error 1.10,  test loss 1.146556, test error 35.70
# Epoch    22, train loss 0.128832, train error 1.10,  test loss 1.155367, test error 35.30
# Epoch    23, train loss 0.119755, train error 0.68,  test loss 1.170683, test error 36.00
# Epoch    24, train loss 0.115543, train error 0.57,  test loss 1.174955, test error 34.90
# Epoch    25, train loss 0.108852, train error 0.45,  test loss 1.192373, test error 35.00
# Epoch    26, train loss 0.102607, train error 0.50,  test loss 1.204675, test error 35.10
# Epoch    27, train loss 0.101464, train error 0.47,  test loss 1.214270, test error 36.60
# Epoch    28, train loss 0.092108, train error 0.25,  test loss 1.219570, test error 34.50
# Epoch    29, train loss 0.089102, train error 0.28,  test loss 1.233832, test error 35.40
# Epoch    30, train loss 0.084986, train error 0.25,  test loss 1.238200, test error 35.10
# Epoch    31, train loss 0.082378, train error 0.22,  test loss 1.239007, test error 34.70
# Epoch    32, train loss 0.080143, train error 0.10,  test loss 1.241736, test error 34.80
# Epoch    33, train loss 0.077911, train error 0.07,  test loss 1.247741, test error 34.80
# Epoch    34, train loss 0.076930, train error 0.07,  test loss 1.259741, test error 34.90
# Epoch    35, train loss 0.074625, train error 0.07,  test loss 1.260425, test error 35.00
# Epoch    36, train loss 0.073041, train error 0.07,  test loss 1.268840, test error 34.90
# Epoch    37, train loss 0.070923, train error 0.03,  test loss 1.268931, test error 34.70
# Epoch    38, train loss 0.069531, train error 0.03,  test loss 1.268702, test error 35.10
# Epoch    39, train loss 0.068195, train error 0.03,  test loss 1.282684, test error 34.60
# Epoch    40, train loss 0.066930, train error 0.03,  test loss 1.282275, test error 35.30
# Epoch    41, train loss 0.066278, train error 0.05,  test loss 1.286823, test error 35.10
# Epoch    42, train loss 0.065441, train error 0.03,  test loss 1.284739, test error 35.10
# Epoch    43, train loss 0.064753, train error 0.03,  test loss 1.287335, test error 35.00
# Epoch    44, train loss 0.064037, train error 0.03,  test loss 1.288993, test error 34.90
# Epoch    45, train loss 0.063428, train error 0.03,  test loss 1.294354, test error 34.80
# Epoch    46, train loss 0.062865, train error 0.03,  test loss 1.293096, test error 35.20
# Epoch    47, train loss 0.062068, train error 0.03,  test loss 1.298300, test error 35.10
# Epoch    48, train loss 0.061400, train error 0.03,  test loss 1.300212, test error 35.40
# Epoch    49, train loss 0.060780, train error 0.03,  test loss 1.302939, test error 35.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
D_i = 40    # Input dimensions
D_k = 200   # Hidden dimensions
D_o = 20    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if type(layer_in) == nn.Linear:
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=200, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=200, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=20, bias=True)
# )

# %%
# TO DO:
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.75)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.633100, train error 63.00,  test loss 1.732047, test error 69.90
# Epoch     1, train loss 1.264817, train error 47.78,  test loss 1.443531, test error 58.70
# Epoch     2, train loss 0.947780, train error 32.03,  test loss 1.205518, test error 46.70
# Epoch     3, train loss 0.799006, train error 26.75,  test loss 1.133795, test error 44.90
# Epoch     4, train loss 0.681135, train error 21.75,  test loss 1.094504, test error 41.50
# Epoch     5, train loss 0.632125, train error 22.53,  test loss 1.141994, test error 42.40
# Epoch     6, train loss 0.458286, train error 13.60,  test loss 1.026575, test error 38.60
# Epoch     7, train loss 0.392048, train error 11.78,  test loss 1.067912, test error 39.00
# Epoch     8, train loss 0.298637, train error 7.28,  test loss 1.072271, test error 40.50
# Epoch     9, train loss 0.253831, train error 6.20,  test loss 1.089621, test error 37.30
# Epoch    10, train loss 0.177589, train error 3.12,  test loss 1.054952, test error 36.30
# Epoch    11, train loss 0.155675, train error 2.75,  test loss 1.120909, test error 39.40
# Epoch    12, train loss 0.106671, train error 1.18,  test loss 1.076650, test error 35.00
# Epoch    13, train loss 0.079044, train error 0.45,  test loss 1.131439, test error 36.50
# Epoch    14, train loss 0.054711, train error 0.18,  test loss 1.108617, test error 36.30
# Epoch    15, train loss 0.040684, train error 0.03,  test loss 1.154494, test error 36.60
# Epoch    16, train loss 0.033803, train error 0.03,  test loss 1.191313, test error 36.50
# Epoch    17, train loss 0.024899, train error 0.00,  test loss 1.167270, test error 35.40
# Epoch    18, train loss 0.020132, train error 0.00,  test loss 1.193453, test error 35.10
# Epoch    19, train loss 0.016586, train error 0.00,  test loss 1.210725, test error 35.10
# Epoch    20, train loss 0.014376, train error 0.00,  test loss 1.217849, test error 34.70
# Epoch    21, train loss 0.013434, train error 0.00,  test loss 1.234866, test error 34.50
# Epoch    22, train loss 0.012437, train error 0.00,  test loss 1.234498, test error 34.30
# Epoch    23, train loss 0.011632, train error 0.00,  test loss 1.250581, test error 35.20
# Epoch    24, train loss 0.010844, train error 0.00,  test loss 1.260999, test error 35.10
# Epoch    25, train loss 0.010308, train error 0.00,  test loss 1.265024, test error 34.40
# Epoch    26, train loss 0.009618, train error 0.00,  test loss 1.280407, test error 34.90
# Epoch    27, train loss 0.009042, train error 0.00,  test loss 1.283418, test error 35.30
# Epoch    28, train loss 0.008545, train error 0.00,  test loss 1.284638, test error 35.00
# Epoch    29, train loss 0.008152, train error 0.00,  test loss 1.293431, test error 34.70
# Epoch    30, train loss 0.007732, train error 0.00,  test loss 1.306564, test error 34.90
# Epoch    31, train loss 0.007422, train error 0.00,  test loss 1.309470, test error 34.70
# Epoch    32, train loss 0.007109, train error 0.00,  test loss 1.319537, test error 34.60
# Epoch    33, train loss 0.006734, train error 0.00,  test loss 1.323890, test error 34.70
# Epoch    34, train loss 0.006463, train error 0.00,  test loss 1.325964, test error 34.80
# Epoch    35, train loss 0.006212, train error 0.00,  test loss 1.333221, test error 35.00
# Epoch    36, train loss 0.006013, train error 0.00,  test loss 1.344686, test error 34.60
# Epoch    37, train loss 0.005753, train error 0.00,  test loss 1.345256, test error 34.70
# Epoch    38, train loss 0.005589, train error 0.00,  test loss 1.355097, test error 34.90
# Epoch    39, train loss 0.005341, train error 0.00,  test loss 1.357471, test error 34.60
# Epoch    40, train loss 0.005237, train error 0.00,  test loss 1.360630, test error 34.70
# Epoch    41, train loss 0.005078, train error 0.00,  test loss 1.362357, test error 34.70
# Epoch    42, train loss 0.004983, train error 0.00,  test loss 1.370845, test error 35.00
# Epoch    43, train loss 0.004856, train error 0.00,  test loss 1.370548, test error 34.80
# Epoch    44, train loss 0.004736, train error 0.00,  test loss 1.377524, test error 34.60
# Epoch    45, train loss 0.004619, train error 0.00,  test loss 1.377227, test error 34.90
# Epoch    46, train loss 0.004525, train error 0.00,  test loss 1.381869, test error 34.70
# Epoch    47, train loss 0.004428, train error 0.00,  test loss 1.382991, test error 34.60
# Epoch    48, train loss 0.004330, train error 0.00,  test loss 1.388847, test error 34.80
# Epoch    49, train loss 0.004228, train error 0.00,  test loss 1.391002, test error 34.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()
